# %%
#testing
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np





df = pd.read_csv(
    "SnP_daily_ReducedGOOGL_NVDA_2024-2026.csv",
    skiprows = [0,2],
    parse_dates=[0]
    )
df.rename(columns={"Ticker": "Date"}, inplace=True)
df.set_index("Date", inplace=True)


googl = df["GOOGL"]
nvda = df["NVDA"]


googl.plot(figsize=  (10,5))
plt.title("GOOGL Price 2024-2026")
plt.ylabel("Close Price/USD")
plt.show()





nvda.plot(figsize=  (10,5))
plt.title("NVDA Price 2024-2026")
plt.ylabel("Close Price/USD")
plt.show()



#r_t = LogP_t - LogP_t-1

"""
#normalized price -- not needed

df_norm = df / df.iloc[0]

df_norm.plot(figsize=(10, 5))
plt.title("Normalized Prices (Base = 1)")
plt.show()
"""
